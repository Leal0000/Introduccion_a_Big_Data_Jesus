# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 


#import matplotlib as plt 
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('https://datautmexample.s3.amazonaws.com/COVID-19_Case_Surveillance_Public_Use_Data.csv')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-3-9fa68f2abc96> in <module>
# ----> 1 data = pd.read_csv('https://datautmexample.s3.amazonaws.com/COVID-19_Case_Surveillance_Public_Use_Data.csv')
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     try:
# --> 454         data = parser.read(nrows)
#     455     finally:
#     456         parser.close()
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1131     def read(self, nrows=None):
#    1132         nrows = _validate_integer("nrows", nrows)
# -> 1133         ret = self._engine.read(nrows)
#    1134
#    1135         # May alter columns / col_dict
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2035     def read(self, nrows=None):
#    2036         try:
# -> 2037             data = self._reader.read(nrows)
#    2038         except StopIteration:
#    2039             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._concatenate_chunks()
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# MemoryError: Unable to allocate 64.1 MiB for an array with shape (8405079,) and data type object

# %%
data
# Out:
#         cdc_report_dt pos_spec_dt    onset_dt             current_status  \
# 0          2020/11/10  2020/11/10         NaN  Laboratory-confirmed case
# 1          2020/11/14  2020/11/10  2020/11/10  Laboratory-confirmed case
# 2          2020/11/19  2020/11/10  2020/11/09  Laboratory-confirmed case
# 3          2020/11/14  2020/11/10         NaN  Laboratory-confirmed case
# 4          2020/11/13  2020/11/10  2020/11/10  Laboratory-confirmed case
# ...               ...         ...         ...                        ...
# 8405074    2020/10/22         NaN         NaN              Probable Case
# 8405075    2020/10/25         NaN         NaN  Laboratory-confirmed case
# 8405076    2020/07/18         NaN         NaN  Laboratory-confirmed case
# 8405077    2020/11/19         NaN         NaN  Laboratory-confirmed case
# 8405078    2020/11/03         NaN         NaN  Laboratory-confirmed case
#
#              sex      age_group Race and ethnicity (combined)  hosp_yn  \
# 0           Male  10 - 19 Years           Black, Non-Hispanic       No
# 1           Male  10 - 19 Years           Black, Non-Hispanic       No
# 2           Male  10 - 19 Years           Black, Non-Hispanic       No
# 3           Male  10 - 19 Years           Black, Non-Hispanic  Missing
# 4           Male  10 - 19 Years           Black, Non-Hispanic       No
# ...          ...            ...                           ...      ...
# 8405074  Missing  30 - 39 Years                       Unknown       No
# 8405075  Missing  30 - 39 Years                       Unknown  Missing
# 8405076  Missing  30 - 39 Years                       Unknown  Missing
# 8405077  Missing  30 - 39 Years                       Unknown  Missing
# 8405078  Missing  30 - 39 Years                       Unknown       No
#
#           icu_yn death_yn medcond_yn
# 0        Unknown       No         No
# 1             No       No         No
# 2             No       No         No
# 3        Missing       No    Missing
# 4             No       No        Yes
# ...          ...      ...        ...
# 8405074  Unknown       No    Missing
# 8405075  Missing  Missing    Missing
# 8405076  Missing  Missing    Missing
# 8405077  Missing  Missing    Missing
# 8405078  Unknown       No    Missing
#
# [8405079 rows x 11 columns]

# %%
relation = data[['cdc_report_dt','pos_spec_dt','onset_dt','current_status']]

# %%
relation
# Out:
#         cdc_report_dt pos_spec_dt    onset_dt             current_status
# 0          2020/11/10  2020/11/10         NaN  Laboratory-confirmed case
# 1          2020/11/14  2020/11/10  2020/11/10  Laboratory-confirmed case
# 2          2020/11/19  2020/11/10  2020/11/09  Laboratory-confirmed case
# 3          2020/11/14  2020/11/10         NaN  Laboratory-confirmed case
# 4          2020/11/13  2020/11/10  2020/11/10  Laboratory-confirmed case
# ...               ...         ...         ...                        ...
# 8405074    2020/10/22         NaN         NaN              Probable Case
# 8405075    2020/10/25         NaN         NaN  Laboratory-confirmed case
# 8405076    2020/07/18         NaN         NaN  Laboratory-confirmed case
# 8405077    2020/11/19         NaN         NaN  Laboratory-confirmed case
# 8405078    2020/11/03         NaN         NaN  Laboratory-confirmed case
#
# [8405079 rows x 4 columns]

# %%
data.columns
# Out:
# Index(['cdc_report_dt', 'pos_spec_dt', 'onset_dt', 'current_status', 'sex',
#        'age_group', 'Race and ethnicity (combined)', 'hosp_yn', 'icu_yn',
#        'death_yn', 'medcond_yn'],
#       dtype='object')

# %%
relation.head(10)
# Out:
#   cdc_report_dt pos_spec_dt    onset_dt             current_status
# 0    2020/11/10  2020/11/10         NaN  Laboratory-confirmed case
# 1    2020/11/14  2020/11/10  2020/11/10  Laboratory-confirmed case
# 2    2020/11/19  2020/11/10  2020/11/09  Laboratory-confirmed case
# 3    2020/11/14  2020/11/10         NaN  Laboratory-confirmed case
# 4    2020/11/13  2020/11/10  2020/11/10  Laboratory-confirmed case
# 5    2020/11/17  2020/11/10  2020/11/08  Laboratory-confirmed case
# 6    2020/11/14  2020/11/10         NaN  Laboratory-confirmed case
# 7    2020/11/10  2020/11/10         NaN  Laboratory-confirmed case
# 8    2020/11/10  2020/11/10         NaN  Laboratory-confirmed case
# 9    2020/11/17  2020/11/10         NaN  Laboratory-confirmed case

# %%
sns.pairplot(relation, kind='reg')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-782585e920e5> in <module>
# ----> 1 sns.pairplot(relation, kind='reg')
#       2 plt.show()
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2092     grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    2093                     hue_order=hue_order, palette=palette, corner=corner,
# -> 2094                     height=height, aspect=aspect, dropna=dropna, **grid_kws)
#    2095
#    2096     # Add the markers here as PairGrid has figured out how many levels of the
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/seaborn/axisgrid.py in __init__(self, data, hue, hue_order, palette, hue_kws, vars, x_vars, y_vars, corner, diag_sharey, height, aspect, layout_pad, despine, dropna, size)
#    1322
#    1323         # Label the axes
# -> 1324         self._add_axis_labels()
#    1325
#    1326         # Sort out the hue variable
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/seaborn/axisgrid.py in _add_axis_labels(self)
#    1541     def _add_axis_labels(self):
#    1542         """Add labels to the left and bottom Axes."""
# -> 1543         for ax, label in zip(self.axes[-1, :], self.x_vars):
#    1544             ax.set_xlabel(label)
#    1545         for ax, label in zip(self.axes[:, 0], self.y_vars):
#
# IndexError: index -1 is out of bounds for axis 0 with size 0

# %%
sns.distplot(data.4)
# Out:
#   File "<ipython-input-23-3a987a868322>", line 1
#     sns.distplot(data.4)
#                       ^
# SyntaxError: invalid syntax

# %%
data.describe()
# Out:
#        cdc_report_dt pos_spec_dt    onset_dt             current_status  \
# count        8405079     2870789     4395957                    8405079
# unique           321         313         338                          2
# top       2020/06/24  2020/11/09  2020/11/02  Laboratory-confirmed case
# freq          155857       50595       49527                    7910118
#
#             sex      age_group Race and ethnicity (combined)  hosp_yn  \
# count   8405061        8404990                       8405072  8405079
# unique        5             10                             9        4
# top      Female  20 - 29 Years                       Unknown       No
# freq    4340898        1635264                       2781176  3502556
#
#          icu_yn death_yn medcond_yn
# count   8405079  8405079    8405079
# unique        4        4          4
# top     Missing       No    Missing
# freq    6178281  3690813    6063390

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8405079 entries, 0 to 8405078
# Data columns (total 11 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   cdc_report_dt                  object
#  1   pos_spec_dt                    object
#  2   onset_dt                       object
#  3   current_status                 object
#  4   sex                            object
#  5   age_group                      object
#  6   Race and ethnicity (combined)  object
#  7   hosp_yn                        object
#  8   icu_yn                         object
#  9   death_yn                       object
#  10  medcond_yn                     object
# dtypes: object(11)
# memory usage: 705.4+ MB

# %%
data.columns
# Out:
# Index(['cdc_report_dt', 'pos_spec_dt', 'onset_dt', 'current_status', 'sex',
#        'age_group', 'Race and ethnicity (combined)', 'hosp_yn', 'icu_yn',
#        'death_yn', 'medcond_yn'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8405079, step=1)
