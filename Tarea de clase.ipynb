# %%
import pandas as pd

# %%
df = pd.read_html("https://finance.yahoo.com/quote/005930.KS/history?p=005930.KS")[0]

# %%
df
# Out:
#                                                   Date  \
# 0                                         Jan 19, 2021
# 1                                         Jan 18, 2021
# 2                                         Jan 15, 2021
# 3                                         Jan 14, 2021
# 4                                         Jan 13, 2021
# ..                                                 ...
# 96                                        Aug 28, 2020
# 97                                        Aug 27, 2020
# 98                                        Aug 26, 2020
# 99                                        Aug 25, 2020
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                   Open  \
# 0                                             84500.00
# 1                                             86600.00
# 2                                             89800.00
# 3                                             88700.00
# ...

# %%
df.drop([0,100])
# Out:
#             Date      Open      High       Low    Close* Adj Close**    Volume
# 1   Jan 18, 2021  86600.00  87300.00  84100.00  85000.00    85000.00  43227951
# 2   Jan 15, 2021  89800.00  91800.00  88000.00  88000.00    88000.00  33431809
# 3   Jan 14, 2021  88700.00  90000.00  88700.00  89700.00    89700.00  26393970
# 4   Jan 13, 2021  89800.00  91200.00  89100.00  89700.00    89700.00  36068848
# 5   Jan 12, 2021  90300.00  91400.00  87800.00  90600.00    90600.00  48682416
# ..           ...       ...       ...       ...       ...         ...       ...
# 95  Aug 31, 2020  56000.00  56100.00  54000.00  54000.00    53669.84  32671367
# 96  Aug 28, 2020  56100.00  56300.00  55400.00  55400.00    55061.29  14619888
# 97  Aug 27, 2020  56300.00  56300.00  55600.00  55600.00    55260.06  16196568
# 98  Aug 26, 2020  56400.00  56500.00  55700.00  56400.00    56055.17  17651593
# 99  Aug 25, 2020  56400.00  56800.00  56100.00  56400.00    56055.17  14021705
#
# [99 rows x 7 columns]

# %%
df = df.astype({"Open":'float',
                "High":'float',
                "Low":'float',
                "Close*":'float',
                "Adj Close**":'float',
                "Volume":'float'})

# %%
df = df.head(30).sort_values(by='Date')

# %%
df.corr()
# Out:
#                  Open      High       Low    Close*  Adj Close**    Volume
# Open         1.000000  0.987765  0.998340  0.985853     0.986151  0.574496
# High         0.987765  1.000000  0.989349  0.997918     0.997730  0.640310
# Low          0.998340  0.989349  1.000000  0.989612     0.990017  0.563368
# Close*       0.985853  0.997918  0.989612  1.000000     0.999970  0.612087
# Adj Close**  0.986151  0.997730  0.990017  0.999970     1.000000  0.609107
# Volume       0.574496  0.640310  0.563368  0.612087     0.609107  1.000000

# %%
df['Gain'] = df['Close*'] - df['Open']

# %%
df
# Out:
#             Date     Open     High      Low   Close*  Adj Close**      Volume  \
# 98  Aug 26, 2020  56400.0  56500.0  55700.0  56400.0     56055.17  17651593.0
# 97  Aug 27, 2020  56300.0  56300.0  55600.0  55600.0     55260.06  16196568.0
# 96  Aug 28, 2020  56100.0  56300.0  55400.0  55400.0     55061.29  14619888.0
# 95  Aug 31, 2020  56000.0  56100.0  54000.0  54000.0     53669.84  32671367.0
# 32  Dec 01, 2020  67100.0  68300.0  67100.0  67800.0     67800.00  22327173.0
# 31  Dec 02, 2020  68400.0  69900.0  68300.0  69500.0     69500.00  29703942.0
# 30  Dec 03, 2020  70100.0  70500.0  69300.0  69700.0     69700.00  23677989.0
# 29  Dec 04, 2020  70400.0  72100.0  70100.0  71500.0     71500.00  28130533.0
# 28  Dec 07, 2020  72400.0  73500.0  71900.0  72900.0     72900.00  28490496.0
# 27  Dec 08, 2020  72200.0  72900.0  71600.0  71700.0     71700.00  25000338.0
# 26  Dec 09, 2020  72100.0  73900.0  72000.0  73900.0     73900.00  24077996.0
# ...
