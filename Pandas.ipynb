# %% [markdown]
#  # pandas
#  Es una libreria de phyton para analizar data frames
#
#
#  # Numpy
#  Es una libreria de phyton para hacer operaciones

# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series([1,2,3,4,5,np.nan,6,8])

# %%
s
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# 5    NaN
# 6    6.0
# 7    8.0
# dtype: float64

# %%
dates = pd.date_range('20150101', periods=60)
dates
# Out:
# DatetimeIndex(['2015-01-01', '2015-01-02', '2015-01-03', '2015-01-04',
#                '2015-01-05', '2015-01-06', '2015-01-07', '2015-01-08',
#                '2015-01-09', '2015-01-10', '2015-01-11', '2015-01-12',
#                '2015-01-13', '2015-01-14', '2015-01-15', '2015-01-16',
#                '2015-01-17', '2015-01-18', '2015-01-19', '2015-01-20',
#                '2015-01-21', '2015-01-22', '2015-01-23', '2015-01-24',
#                '2015-01-25', '2015-01-26', '2015-01-27', '2015-01-28',
#                '2015-01-29', '2015-01-30', '2015-01-31', '2015-02-01',
#                '2015-02-02', '2015-02-03', '2015-02-04', '2015-02-05',
#                '2015-02-06', '2015-02-07', '2015-02-08', '2015-02-09',
#                '2015-02-10', '2015-02-11', '2015-02-12', '2015-02-13',
#                '2015-02-14', '2015-02-15', '2015-02-16', '2015-02-17',
#                '2015-02-18', '2015-02-19', '2015-02-20', '2015-02-21',
# ...

# %%
type(dates)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
pandas_dates = pd.DataFrame({'dates_column':dates})

# %%
pandas_dates.head(5)
# Out:
#   dates_column
# 0   2015-01-01
# 1   2015-01-02
# 2   2015-01-03
# 3   2015-01-04
# 4   2015-01-05

# %%
type(pandas_dates)
# Out:
# pandas.core.frame.DataFrame

# %%
df2 = pd.DataFrame({'Numero' : 1 , 
                    'Fecha' : pd.data_range('2014',periods = 4) , 
                    'Rango' : pd.Series(1 , index = list(range(4))), dtype = 'float32' , 
                    'Flotante' : np.array[3]*4, dtype='float32',
                    'Lista' : pd.Categorical(['test' , 'train' , 'try' , 'test']) , 
                    'String' : 'foo'})
# Out:
#   File "<ipython-input-10-defbf8994ef0>", line 3
#     'Rango' : pd.Series(1 , index = list(range(4))), dtype = 'float32' ,
#                                                            ^
# SyntaxError: invalid syntax

# %%
df2 = pd.DataFrame({'Numero':1,
                    'Fecha':pd.date_range('2014',periods=4),
                    'Rango':pd.Series(1, index=list(range(4)), dtype='float32'),
                    'Flotante': np.array([3]*4, dtype='float32'),
                    'Lista': pd.Categorical(['test','train','try','test']),
                    'String': 'foo'})

# %%
df2
# Out:
#    Numero      Fecha  Rango  Flotante  Lista String
# 0       1 2014-01-01    1.0       3.0   test    foo
# 1       1 2014-01-02    1.0       3.0  train    foo
# 2       1 2014-01-03    1.0       3.0    try    foo
# 3       1 2014-01-04    1.0       3.0   test    foo

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 0 to 3
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Numero    4 non-null      int64
#  1   Fecha     4 non-null      datetime64[ns]
#  2   Rango     4 non-null      float32
#  3   Flotante  4 non-null      float32
#  4   Lista     4 non-null      category
#  5   String    4 non-null      object
# dtypes: category(1), datetime64[ns](1), float32(2), int64(1), object(1)
# memory usage: 268.0+ bytes

# %% [markdown]
# # Ver nuestros datos

# %% [markdown]
# ver nuestros primeros datos

# %%
df2.head(2)
# Out:
#    Numero      Fecha  Rango  Flotante  Lista String
# 0       1 2014-01-01    1.0       3.0   test    foo
# 1       1 2014-01-02    1.0       3.0  train    foo

# %% [markdown]
# Ver uestros ultimos datos

# %%
df2.tail(2)
# Out:
#    Numero      Fecha  Rango  Flotante Lista String
# 2       1 2014-01-03    1.0       3.0   try    foo
# 3       1 2014-01-04    1.0       3.0  test    foo

# %%
df2.index
# Out:
# Int64Index([0, 1, 2, 3], dtype='int64')

# %%
df2.columns
# Out:
# Index(['Numero', 'Fecha', 'Rango', 'Flotante', 'Lista', 'String'], dtype='object')

# %%
df2.describe()
# Out:
#        Numero  Rango  Flotante
# count     4.0    4.0       4.0
# mean      1.0    1.0       3.0
# std       0.0    0.0       0.0
# min       1.0    1.0       3.0
# 25%       1.0    1.0       3.0
# 50%       1.0    1.0       3.0
# 75%       1.0    1.0       3.0
# max       1.0    1.0       3.0

# %%
df2.corr()
# Out:
#           Numero  Rango  Flotante
# Numero       NaN    NaN       NaN
# Rango        NaN    NaN       NaN
# Flotante     NaN    NaN       NaN

# %%
df2.T
# Out:
#                             0                    1                    2  \
# Numero                      1                    1                    1
# Fecha     2014-01-01 00:00:00  2014-01-02 00:00:00  2014-01-03 00:00:00
# Rango                       1                    1                    1
# Flotante                    3                    3                    3
# Lista                    test                train                  try
# String                    foo                  foo                  foo
#
#                             3
# Numero                      1
# Fecha     2014-01-04 00:00:00
# Rango                       1
# Flotante                    3
# Lista                    test
# String                    foo

# %%
df2.sort_values(by = 'Lista')
# Out:
#    Numero      Fecha  Rango  Flotante  Lista String
# 0       1 2014-01-01    1.0       3.0   test    foo
# 3       1 2014-01-04    1.0       3.0   test    foo
# 1       1 2014-01-02    1.0       3.0  train    foo
# 2       1 2014-01-03    1.0       3.0    try    foo

# %%
random = pd.DataFrame(np.random.randn(60,4), index=dates , columns=list('ABCD'))

# %%
random.head(5)
# Out:
#                    A         B         C         D
# 2015-01-01  2.056902 -1.470659 -0.681317  1.303271
# 2015-01-02 -0.894423  0.060055  0.629302 -0.714102
# 2015-01-03  1.320831 -1.002814 -2.074601 -0.354827
# 2015-01-04 -1.223894 -1.051236  1.438865 -1.358640
# 2015-01-05 -0.518273  0.022688 -0.989575  0.916891

# %% [markdown]
# # FC
# random.loc [filas,columnas]

# %%
random.loc[ : , ['A','B']]
# Out:
#                    A         B
# 2015-01-01  2.056902 -1.470659
# 2015-01-02 -0.894423  0.060055
# 2015-01-03  1.320831 -1.002814
# 2015-01-04 -1.223894 -1.051236
# 2015-01-05 -0.518273  0.022688
# 2015-01-06  0.004868  0.123980
# 2015-01-07  0.961957 -0.512798
# 2015-01-08 -0.596216  0.892755
# 2015-01-09  0.138177  0.577435
# 2015-01-10  0.813754 -0.442994
# 2015-01-11  0.152507  0.688043
# 2015-01-12 -0.977488 -0.228941
# 2015-01-13  0.499917 -0.211517
# 2015-01-14  1.271602  0.423193
# 2015-01-15  0.114027  1.309387
# 2015-01-16  0.590911 -0.674116
# 2015-01-17  0.722041  0.712098
# 2015-01-18 -1.336260 -0.183097
# 2015-01-19  0.589458  0.302770
# 2015-01-20  1.012409  0.477959
# 2015-01-21  0.029843 -0.822776
# 2015-01-22 -1.764886 -0.192461
# 2015-01-23  1.559802  1.328960
# 2015-01-24  0.298109  1.823098
# 2015-01-25 -1.236651 -0.431847
# 2015-01-26  0.507545  0.523494
# 2015-01-27 -0.298624  0.561756
# 2015-01-28  1.152101  0.613801
# 2015-01-29 -1.405286  1.057712
# ...

# %%
random.loc['2015-01-02', ['A' , 'B']]
# Out:
# A   -0.894423
# B    0.060055
# Name: 2015-01-02 00:00:00, dtype: float64

# %%
random.loc['2015-01-02', ['C' , 'D']]
# Out:
# C    0.629302
# D   -0.714102
# Name: 2015-01-02 00:00:00, dtype: float64

# %%
pandas_dates.loc['1' : '15']
# Out:
#    dates_column
# 1    2015-01-02
# 2    2015-01-03
# 3    2015-01-04
# 4    2015-01-05
# 5    2015-01-06
# 6    2015-01-07
# 7    2015-01-08
# 8    2015-01-09
# 9    2015-01-10
# 10   2015-01-11
# 11   2015-01-12
# 12   2015-01-13
# 13   2015-01-14
# 14   2015-01-15
# 15   2015-01-16
